# %%
import numpy as np
import pandas as pd
# from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

def step_gradient(data,lr,m):
    N = len(data)
    n = len(m)
    m_slope = np.zeros(n)
    m_new = np.zeros(n)
    for i in range(N):
        a = np.dot(m,data[i][:-1])
        for j in range(n):
            x = data[i,j]
            y = data[i,n]
            m_slope[j] += (-2/N)*(y-a)*x
            m_new[j] = m[j]-lr*m_slope[j]
    return m_new


def cost(data,m):
    total_cost = 0
    N = len(data)
    n = len(m)
    for i in range(N):
        a = np.dot(m,data[i][:-1])
        y = data[i,n]
        total_cost += (1/N)*((y-a)**2)
    return total_cost

def gd(data,lr,ni):
#     m=np.zeros(len(data[0][:-1]))
    m = [-13.58021379,-3.72607364,0.75011062,-1.7799166,0.82516999,1.21179467,-0.04608281,-0.67160861,-0.19828822,0.31213655,0.08630741,-0.29925842,-0.36591454,-0.35089885,453.23503987074747]
    for i in range(ni):
        m = step_gradient(data,lr,m)
        print("Cost ",i, " ", cost(data,m))
    return m

def predict(m,test_data):
    c = m[-1]
    m = m[:-1]
    Y_pred = []
    for i in range(len(test_data)):
        Y_pred.append(np.dot(test_data[i],m))
        Y_pred[i] += c
    return Y_pred

def run():
    boston = np.loadtxt("C:/Users/Dhruv/Desktop/Machine Learning/Datasets/New Folder/0000000000002419_training_ccpp_x_y_train.csv", delimiter = ",")
    boston_test = np.loadtxt("C:/Users/Dhruv/Desktop/Machine Learning/Datasets/New Folder/0000000000002419_test_ccpp_x_test.csv", delimiter = ",")
    print("boston ",boston.shape)
    X = boston
#     X = np.insert(boston,-1,1,axis=1)
#     boston_test = np.insert(boston_test,-1,1,axis=1)
    print("boston_test ",boston_test.shape)
#     print("X (after inserting 1) ",X.shape)
    # print(X)
    input = X[:,:-1]
    Y = X[:,-1]
    scalar = preprocessing.StandardScaler()
    scalar.fit(input)
    input = scalar.transform(input)
    
    df = pd.DataFrame(input)
    df.columns  = ['TAX','PTRATIO', 'B', 'LSTAT']
    
    for i in  range(4):
        for j in range(i,4):
            first = df.columns[i]
            second = df.columns[j]
            name =  first + "_" + second
            df[name] = df[first]*df[second]
    
    input = df.values
    
    # print(X[:,:-1].shape)
#     input = X[:,:-1]
#     Y = X[:,-1]
    print("input ",input.shape)
    print("Y " ,Y.shape)
    
    lr = 0.00001
    ni = 150
    
    print("transformed input :", input.shape)
    
    Y = Y.tolist()
    input = input.tolist()
    for i in range(len(input)):
        input[i].append(Y[i])
    input = np.array(input)
    Y = np.array(Y)
    
    input = np.insert(input,-1,1,axis=1)
    print("input afet appending Y & 1 :",input.shape)
    
    m = gd(input,lr,ni)
    print(m.shape)
    
    boston_test = scalar.transform(boston_test)
    
    df2 = pd.DataFrame(boston_test)
    df2.columns  = ['TAX','PTRATIO', 'B', 'LSTAT']

    for i in  range(4):
        for j in range(i,4):
            first = df2.columns[i]
            second = df2.columns[j]
            name =  first + "_" + second
            df2[name] = df2[first]*df2[second]
            
    boston_test = df2.values
    
    
    print(boston_test.shape)
#     boston_test = np.insert(boston_test,-1,1,axis=1)
#     print("boston_test after appending 1 :", boston_test.shape)
    Y_final = predict(m,boston_test)
    print(len(Y_final))
    print(Y_final)
    np.savetxt("C:/Users/Dhruv/Desktop/Machine Learning/Datasets/New Folder/predictions2.csv",Y_final)

run()
# Out:
# boston  (7176, 5)
# boston_test  (2392, 4)
# input  (7176, 14)
# Y  (7176,)
# transformed input : (7176, 14)
# input afet appending Y & 1 : (7176, 16)
# Cost  0   18.24653854175042
# Cost  1   18.246538541750432
# Cost  2   18.24653854175042
# Cost  3   18.246538541750493
# Cost  4   18.246538541750475
# Cost  5   18.246538541750564
# Cost  6   18.246538541750464
# Cost  7   18.246538541750464
# Cost  8   18.246538541750443
# Cost  9   18.24653854175045
# Cost  10   18.24653854175051
# Cost  11   18.24653854175045
# Cost  12   18.246538541750493
# Cost  13   18.24653854175044
# Cost  14   18.246538541750457
# Cost  15   18.246538541750493
# Cost  16   18.2465385417504
# Cost  17   18.24653854175045
# Cost  18   18.246538541750443
# Cost  19   18.24653854175044
# Cost  20   18.246538541750432
# Cost  21   18.246538541750397
# Cost  22   18.24653854175041
# Cost  23   18.246538541750457
# Cost  24   18.24653854175045
# Cost  25   18.246538541750507
# Cost  26   18.246538541750496
# Cost  27   18.246538541750503
# Cost  28   18.246538541750443
# Cost  29   18.24653854175045
# Cost  30   18.246538541750454
# Cost  31   18.246538541750446
# Cost  32   18.24653854175045
# Cost  33   18.246538541750475
# Cost  34   18.24653854175043
# Cost  35   18.246538541750475
# Cost  36   18.2465385417505
# Cost  37   18.246538541750574
# Cost  38   18.246538541750503
# Cost  39   18.24653854175052
# Cost  40   18.246538541750525
# Cost  41   18.24653854175052
# Cost  42   18.246538541750464
# Cost  43   18.24653854175052
# Cost  44   18.24653854175056
# Cost  45   18.246538541750557
# Cost  46   18.246538541750457
# Cost  47   18.246538541750503
# Cost  48   18.246538541750407
# Cost  49   18.24653854175046
# Cost  50   18.246538541750486
# Cost  51   18.246538541750475
# Cost  52   18.246538541750496
# Cost  53   18.246538541750493
# Cost  54   18.246538541750446
# Cost  55   18.24653854175042
# Cost  56   18.24653854175041
# Cost  57   18.246538541750386
# Cost  58   18.246538541750457
# Cost  59   18.246538541750446
# Cost  60   18.24653854175047
# Cost  61   18.246538541750404
# Cost  62   18.24653854175041
# Cost  63   18.24653854175047
# Cost  64   18.246538541750475
# Cost  65   18.24653854175046
# Cost  66   18.24653854175048
# Cost  67   18.246538541750475
# Cost  68   18.246538541750436
# Cost  69   18.24653854175044
# Cost  70   18.246538541750414
# Cost  71   18.246538541750407
# Cost  72   18.246538541750443
# Cost  73   18.246538541750393
# Cost  74   18.24653854175047
# Cost  75   18.246538541750446
# Cost  76   18.246538541750418
# Cost  77   18.246538541750425
# Cost  78   18.246538541750464
# Cost  79   18.2465385417504
# Cost  80   18.246538541750414
# Cost  81   18.246538541750464
# Cost  82   18.246538541750486
# Cost  83   18.24653854175047
# Cost  84   18.246538541750418
# Cost  85   18.246538541750496
# Cost  86   18.246538541750414
# Cost  87   18.246538541750404
# Cost  88   18.246538541750443
# Cost  89   18.246538541750432
# Cost  90   18.246538541750454
# Cost  91   18.246538541750475
# Cost  92   18.24653854175052
# Cost  93   18.24653854175049
# Cost  94   18.24653854175045
# Cost  95   18.246538541750507
# Cost  96   18.24653854175046
# Cost  97   18.2465385417504
# Cost  98   18.246538541750432
# Cost  99   18.24653854175044
# Cost  100   18.246538541750493
# Cost  101   18.24653854175043
# Cost  102   18.246538541750496
# Cost  103   18.24653854175047
# Cost  104   18.246538541750496
# Cost  105   18.2465385417505
# Cost  106   18.246538541750493
# Cost  107   18.24653854175045
# Cost  108   18.24653854175052
# Cost  109   18.24653854175047
# Cost  110   18.246538541750496
# Cost  111   18.246538541750535
# Cost  112   18.246538541750454
# Cost  113   18.246538541750407
# Cost  114   18.24653854175042
# Cost  115   18.246538541750414
# Cost  116   18.24653854175042
# Cost  117   18.246538541750414
# Cost  118   18.246538541750436
# Cost  119   18.246538541750397
# Cost  120   18.2465385417504
# Cost  121   18.24653854175037
# Cost  122   18.246538541750436
# Cost  123   18.246538541750432
# Cost  124   18.246538541750414
# Cost  125   18.246538541750464
# Cost  126   18.246538541750365
# Cost  127   18.24653854175049
# Cost  128   18.246538541750443
# Cost  129   18.246538541750475
# Cost  130   18.246538541750375
# Cost  131   18.246538541750432
# Cost  132   18.24653854175039
# Cost  133   18.246538541750432
# Cost  134   18.246538541750493
# Cost  135   18.24653854175046
# Cost  136   18.246538541750443
# Cost  137   18.246538541750475
# Cost  138   18.246538541750457
# Cost  139   18.246538541750528
# Cost  140   18.246538541750493
# Cost  141   18.246538541750468
# Cost  142   18.246538541750354
# Cost  143   18.246538541750397
# Cost  144   18.246538541750372
# Cost  145   18.246538541750436
# Cost  146   18.24653854175042
# Cost  147   18.24653854175051
# Cost  148   18.246538541750496
# Cost  149   18.24653854175048
# (15,)
# (2392, 14)
# 2392
# [470.6170442971824, 472.8974334987818, 433.3312209819057, 455.3620731468336, 464.1309514954902, 447.18261260197875, 479.04946237961707, 444.7180521195794, 487.31044070945904, 439.5158571749566, 435.978254321197, 432.3131655774206, 472.45749169249905, 462.7902471278035, 444.4883790038865, 455.43290593437234, 491.3365522306355, 446.2940114911366, 428.0331616691699, 440.28205197683724, 439.34441112471785, 486.62385138517817, 458.30909442803727, 477.6305948558549, 432.3770155011555, 435.62010295953246, 468.04548474762726, 470.5398946574151, 434.93712357943735, 477.96672252983785, 441.18154151245596, 433.6571632273667, 447.91633671061095, 470.78329181310875, 469.77244713842316, 473.13792908118717, 446.36148055658595, 454.246169362987, 442.51309657384394, 484.4476555543151, 465.61982917054337, 432.1698803282667, 474.71453347293124, 467.1702863464108, 460.0255357750548, 483.1399425650337, 437.7355729687102, 428.9574871576232, 439.6540849055198, 476.00479154657165, 474.61196722543207, 465.248151813518, 467.28418483916914, 436.8031171185484, 463.3254424530316, 433.52358757299385, 441.1142016537225, 440.7880853309966, 473.1169839981532, 452.9381056145002, 484.74173157296457, 451.72039668928585, 443.8933162868063, 467.98081217805975, 439.68502161274455, 482.23370769630657, 466.04876516713284, 456.03020958953357, 488.73964149938485, 437.4694830204833, 442.3101223506418, 465.03597316646096, 439.91005425152014, 430.08813049046637, 464.4411214682302, 473.65272253320893, 444.51922985492763, 428.723981912892, 434.1134447387141, 447.60374823477775, 433.76178532718734, 435.1034222363487, 447.6024435848714, 447.53593499248746, 464.32928387421356, 445.38953431049515, 463.4604490358955, 450.7570655105959, 483.2590671708024, 458.04195466557564, 443.2367755359529, 430.5970068979342, 473.8688070737685, 455.62762060803084, 445.23457315477935, 440.96599595861437, 442.1636644406279, 440.7249826393154, 437.9788903476734, 469.380000840417, 443.0251002039425, 429.9716159612122, 466.18852567963484, 481.3191859093831, 470.5242270430684, 466.74554172234394, 481.31888430817537, 463.43583412318566, 435.08397017505973, 451.9252951515367, 445.5240234427029, 438.8748414386507, 443.96788785168286, 443.71025568435766, 445.04734986037295, 434.9342154378881, 471.68987385363806, 465.120341143847, 450.5996504917239, 481.627386712326, 436.9101346799467, 433.32539532044086, 434.8666919562959, 440.27471540629097, 440.4400363046025, 434.19846164389196, 442.37938715098966, 435.9921700063803, 431.73262999602235, 450.51262834780465, 441.68141102811046, 440.2042085959821, 444.64783807761825, 448.4910355779141, 448.41265702654783, 446.43195311715357, 472.33125069306607, 446.6960320755625, 446.8261158382928, 453.55246832842, 474.6164435506072, 468.6347821678331, 476.1494432273495, 465.04525468003936, 473.0519810193656, 440.3661551027122, 450.457702265942, 444.78566139805156, 450.02698274899745, 492.1234949752962, 434.2263793659674, 464.2639855223493, 451.1358214826853, 443.28513775267925, 470.98910709333177, 447.43078068207126, 464.14243973289484, 437.702152490665, 457.0674139031493, 465.36208758038856, 449.85402060749595, 436.0355297369975, 468.60256801270674, 458.4459547065301, 470.285544095293, 436.7309013396512, 454.5141819292947, 463.7310303236245, 430.6559502358863, 437.6562920212341, 493.21751199697167, 460.8344693754538, 443.3720638240373, 466.6338370760206, 462.327641382491, 461.74531393842767, 435.4495623680133, 469.92189406083645, 438.31526164406347, 464.7400245357793, 434.132939005452, 448.74057751965495, 463.6490833095861, 436.78300625085603, 460.52716833051943, 450.2743998277655, 441.56752091339195, 473.9535896818536, 473.6895853594626, 472.88571536072993, 479.09925604281096, 475.4892424457879, 472.90776322771467, 469.0138524288422, 442.51585458106325, 469.71513817390144, 457.7558768708567, 485.67195726177283, 444.87742322705975, 443.780376915796, 474.6038511988897, 470.4838146874525, 448.15084971866827, 473.3965599763284, 488.12620945610433, 431.03476406305793, 435. ...

# %%
[469.69639146066726, 471.3600839066143, 432.60547125788906, 460.12759777657567, 469.05840229782586, 440.04938766326836, 478.1391506184523, 440.72373908521985, 486.1917092339465, 433.91799634543, 436.46301969359416, 439.1310119104565, 471.14123764406077, 466.95914780805833, 443.8054809021325, 450.2595805507383, 496.5194398861057, 441.27990370734244, 432.2942697547095, 441.83996415778216, 440.63964180821137, 485.83858398478014, 449.66267739944107, 473.0095814650748, 433.11391406888686, 433.1180701033427,
# Out:
#   File "<ipython-input-2-34476c93010d>", line 1
#     [469.69639146066726, 471.3600839066143, 432.60547125788906, 460.12759777657567, 469.05840229782586, 440.04938766326836, 478.1391506184523, 440.72373908521985, 486.1917092339465, 433.91799634543, 436.46301969359416, 439.1310119104565, 471.14123764406077, 466.95914780805833, 443.8054809021325, 450.2595805507383, 496.5194398861057, 441.27990370734244, 432.2942697547095, 441.83996415778216, 440.63964180821137, 485.83858398478014, 449.66267739944107, 473.0095814650748, 433.11391406888686, 433.1180701033427,
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# SyntaxError: unexpected EOF while parsing
