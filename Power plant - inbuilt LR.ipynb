# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

def step_gradient(data,lr,m):
    N = len(data)
    n = len(m)
    m_slope = np.zeros(n)
    m_new = np.zeros(n)
    for i in range(N):
        a = np.dot(m,data[i][:-1])
        for j in range(n):
            x = data[i,j]
            y = data[i,n]
            m_slope[j] += (-2/N)*(y-a)*x
            m_new[j] = m[j]-lr*m_slope[j]
    return m_new


def cost(data,m):
    total_cost = 0
    N = len(data)
    n = len(m)
    for i in range(N):
        a = np.dot(m,data[i][:-1])
        y = data[i,n]
        total_cost += (1/N)*((y-a)**2)
    return total_cost

def gd(data,lr,ni):
    m=np.zeros(len(data[0][:-1]))
    for i in range(ni):
        m = step_gradient(data,lr,m)
        print("Cost ",i, " ", cost(data,m))
    return m

def predict(m,test_data):
    c = m[-1]
    m = m[:-1]
    Y_pred = []
    for i in range(len(test_data)):
        Y_pred.append(np.dot(test_data[i],m))
        Y_pred[i] += c
    return Y_pred

def run():
    boston = np.loadtxt("C:/Users/Dhruv/Desktop/Machine Learning/Datasets/New Folder/0000000000002419_training_ccpp_x_y_train.csv", delimiter = ",")
    boston_test = np.loadtxt("C:/Users/Dhruv/Desktop/Machine Learning/Datasets/New Folder/0000000000002419_test_ccpp_x_test.csv", delimiter = ",")
    print("boston ",boston.shape)
    poly = preprocessing.PolynomialFeatures(7)
    X = boston
#     X = np.insert(boston,-1,1,axis=1)
#     boston_test = np.insert(boston_test,-1,1,axis=1)
    print("boston_test ",boston_test.shape)
#     print("X (after inserting 1) ",X.shape)
    # print(X)
    input = X[:,:-1]
    Y = X[:,-1]
    scalar = preprocessing.StandardScaler()
    scalar.fit(input)
    input = scalar.transform(input)
    
#     df = pd.DataFrame(input)
#     df.columns  = ['TAX','PTRATIO', 'B', 'LSTAT']
    
#     for i in  range(4):
#         for j in range(i,4):
#             first = df.columns[i]
#             second = df.columns[j]
#             name =  first + "_" + second
#             df[name] = df[first]*df[second]
    
#     input = df.values
    input = poly.fit_transform(input)
    clf = LinearRegression()
    clf.fit(input,Y)
    
    # print(X[:,:-1].shape)
#     input = X[:,:-1]
#     Y = X[:,-1]
    print("input ",input.shape)
    print("Y " ,Y.shape)
    
    lr = 0.1
    ni = 150
    
    print("transformed input :", input.shape)
    
    Y = Y.tolist()
    input = input.tolist()
    for i in range(len(input)):
        input[i].append(Y[i])
    input = np.array(input)
    Y = np.array(Y)
    
    input = np.insert(input,-1,1,axis=1)
    print("input afet appending Y & 1 :",input.shape)
    
#     m = gd(input,lr,ni)
#     print(m.shape)
    
    boston_test = scalar.transform(boston_test)
    
#     df2 = pd.DataFrame(boston_test)
#     df2.columns  = ['TAX','PTRATIO', 'B', 'LSTAT']

#     for i in  range(4):
#         for j in range(i,4):
#             first = df2.columns[i]
#             second = df2.columns[j]
#             name =  first + "_" + second
#             df2[name] = df2[first]*df2[second]
            
#     boston_test = df2.values
    
    boston_test = poly.transform(boston_test)
    print(boston_test.shape)
#     boston_test = np.insert(boston_test,-1,1,axis=1)
#     print("boston_test after appending 1 :", boston_test.shape)
#     Y_final = predict(m,boston_test)
    Y_pred = clf.predict(boston_test)
    print(len(Y_pred))
    print(clf.coef_, clf.intercept_)
#     print(len(Y_final))
#     print(Y_final)
    np.savetxt("C:/Users/Dhruv/Desktop/Machine Learning/Datasets/New Folder/predictions3.csv",Y_pred)
    
run()
# Out:
# boston  (7176, 5)
# boston_test  (2392, 4)
# input  (7176, 330)
# Y  (7176,)
# transformed input : (7176, 330)
# input afet appending Y & 1 : (7176, 332)
# (2392, 330)
# 2392
# [ 2.44761203e-11 -1.08032611e+01 -6.21068127e-01  3.39389524e+00
#  -5.32392948e-01  3.85197993e+00 -5.61859122e+00 -1.14441310e+00
#   6.94961763e-01  2.95558545e+00 -8.62859486e-01 -4.43897189e+00
#  -1.14750242e+00 -1.00741439e+00  5.25905949e-01 -3.56485831e+00
#  -6.40313276e+00 -3.34807930e+00 -1.55809808e+00  7.41185032e+00
#  -2.73814054e+00 -7.51225871e+00 -5.24985590e+00 -3.95764564e+00
#  -1.66810382e+00 -9.23690288e+00  3.39780444e-01  4.27371291e+00
#   1.82346236e-01 -2.02270547e+00 -9.94351643e-01 -1.47919468e+00
#  -1.90664184e+00 -2.11279219e+00 -3.65417774e-01 -1.43348486e-01
#  -2.51665534e+00 -8.62690054e+00 -5.84080324e+00  9.90244431e+00
#   1.87005396e+00  1.09142629e+01 -1.25852523e+01 -1.15086472e+01
#  -6.02898316e+00 -5.94756936e+00  1.26406380e+01 -6.84124085e+00
#   1.57660878e+01  1.44499638e+01  9.60316084e+00 -1.76864171e+00
#  -7.26561940e+00 -1.29510138e+00 -2.04972325e-01  4.54948957e-01
#  -3.36460054e+00  5.73996192e+00 -4.44035832e+00 -5.03572557e+00
#  -3.64315717e+00  1.90127992e+00  7.43579192e+00  7.44011294e-01
#   7.85585183e-01  3.74284065e-01  9.85807600e-01 -8.06731356e-01
#   2.15751833e-02 -2.56247492e-01  3.84190359e-01  9.45431248e+00
#   5.09197998e+00 -3.59302165e-01 -1.40390236e+01 -1.11011186e+01
#   1.81797767e+01  7.09493117e+00  1.39669374e+01  1.50267884e+00
#   1.49545083e+01  8.87845560e+00 -2.97788719e+01 -1.87475864e+01
#  -1.59844964e+01  8.27085931e+00 -6.59135283e-01  1.08822026e+01
#   1.60397898e+01  4.55794642e-01 -9.86997486e+00 -2.89727386e-01
#   2.47045962e+01  1.37161182e+01 -2.62544800e+00 -1.04891378e+01
#   1.55219424e+00 -1.17399634e+01 -1.47226879e+01  3.20270721e+00
#   1.18802256e+00  2.50347454e+00  8.48946809e+00  7.41946597e+00
#   2.66151124e-01  5.30807620e+00 -2.12372497e+00 -8.22543702e+00
#   3.76818156e-01  7.78983415e+00  3.89229571e+00  1.35887428e+00
#   2.06265302e+00  1.43273161e+00 -2.46788760e+00 -4.21095579e-02
#  -3.11283025e-01 -5.54473090e+00 -3.26455103e+00  3.74425824e-01
#   2.24967784e-01  7.26586664e-01  1.32915900e+00  1.96773734e+00
#   1.10441547e+00 -2.27148576e-02  1.54103923e+00 -3.49691845e+00
#   9.05493323e+00  4.62095979e+00  4.29626141e+00 -1.42250456e+01
#  -4.58150324e+00  1.10620383e+01  1.39052551e+01  3.13777730e+00
#  -2.39847761e-01  1.25057058e+01  6.97300973e+00 -1.66921354e+01
#  -1.43186863e+01  2.68013302e+00  4.90201949e+00  1.36413770e+01
#   5.79687281e+00  1.85812923e-01 -7.95046476e+00 -5.62936211e+00
#  -1.15325802e+01  1.26310713e+01  1.34671313e+01 -3.49412213e+00
#  -7.15914237e+00 -1.58311764e+01  2.12346870e+00  2.49535759e+00
#   1.34969816e+00  3.35355391e+00  4.68197419e+00  1.14227053e+00
#   4.06808162e-01  6.03544770e+00 -4.83732929e+00  5.24722139e+00
#  -8.85854913e+00 -1.45969577e+01 -2.54938923e+00  1.08977205e+00
#   8.77646453e+00 -2.95735056e+00 -2.15290621e+00 -3.62577498e+00
#  -5.77634499e+00 -2.50198554e+00  7.75006522e-01 -1.12682933e+00
#  -2.84477615e-01 -6.47631709e-01 -6.44361357e-02  7.71412131e-01
#  -7.61470876e-03  2.48034773e-02 -1.09977370e+00  1.97259734e+00
#  -1.95119397e+00  2.26859291e+00  4.76247053e+00  1.47820071e+00
#   5.58253400e-01 -4.54209684e+00 -8.76892448e-01  2.36353958e-01
#   1.49725617e+00  6.85859101e-01  4.35244396e-01  1.34704026e-01
#   5.02694122e-01 -5.21529550e-02 -1.38488977e+00 -5.92247720e-01
#  -3.59898407e-02  3.28687305e-01 -1.68419293e-01 -6.61133555e-02
#  -6.19063778e-01 -4.72804128e-01 -1.48360405e-01  2.51292030e-01
#   5.24090318e-02  5.72194943e-02 -2.15626291e-01  3.35071540e+00
#  -2.76842926e+00 -5.82483262e-02 -8.83075747e+00  2.29016487e+01
#   5.52546131e+00 -3.50331307e+00 -7.81696919e+00  1.79847474e+00
#   3.34200601e+00 -4.19245392e+01 -8.21930348e+00  2.58327552e+01
#   4.33076713e+01 -2.01009824e+00 -2.37953125e-01 -4.63848826e+00
#  -9.26419080e+00  2.43011276e+00  5.57437079e+00  2.66088504e+01
#  -9.87868836e+00 -4.23129911e+01 -5.77645945e+01  1.28474041e+00
#   6.21989993e+00  3.00826012e+01  3.71364785e+01 -6.79812701e+00
#   2.42742134e-01  9.35274816e-01 -4.43353678e+00 -6.35552999e+00
#   7.34272973e-01 -4.55551774e+00 -4.69469244e+00  2.05487188e+01
#   2.27464707e+01  1.83318563e+01 -5.04001400e+00 -1.06578907e+01
#  -3.93884975e+01 -4.19143238e+01  9.35909440e+00  1.60830040e+00
#   1.98716091e+00  1.77512419e+01  1.67078522e+01 -3.13559945e+00
#   5.83361110e-01  6.20240908e-01 -2.41782882e-01 -3.00268795e+00
#  -2.70093348e+00 -1.81977692e-01  1.09198629e+00  7.50743259e-01
#  -1.02666422e+01 -1.38864173e+00  9.43327724e+00  4.35207005e+00
#   3.38800092e+00  1.17424744e+01  1.57491030e+01 -6.33609951e+00
#  -4.66430834e+00 -7.23624219e+00 -1.66038883e+01 -1.21022968e+01
#   4.16418708e+00 -1.29390574e+00 -1.52365976e+00  8.90528263e-01
#   5.79697176e+00  3.58809647e+00 -5.52467273e-01 -2.24753822e-02
#   2.08129911e-01 -4.79664907e-01 -7.25339849e-01 -1.03438273e+00
#  -9.79358347e-01 -1.92338416e-01 -3.89988094e-01  4.23245367e-02
#   2.00120722e+00 -1.63972432e+00 -4.99470907e+00 -7.34778789e-01
#  -1.61074390e-01  1.91427834e+00 -3.26124580e-01  1.52992253e+00
#   1.46383375e+00  1.76342075e+00  3.64366621e+00  2.27402256e+00
#  -1.41063886e+00  2.00422506e-01 -1.13851015e+00 -1.66063173e+00
#  -2.17166135e+00 -9.79931991e-01  6.88575273e-01 -5.46581469e-02
#  -8.30358433e-01 -8.71871198e-02  4.73553595e-01  9.54391434e-01
#   5.34576699e-01  1.82612578e-02 -3.69584630e-03 -3.08230960e-02
#  -8.58080529e-02 -2.63107338e-01 -1.17378277e-01 -1.52686391e-01
#  -1.13678358e-01 -1.71881249e-02] 452.6297403767817

# %%
m = [-13.58021379,-3.72607364,0.75011062,-1.7799166,0.82516999,1.21179467,-0.04608281,-0.67160861,-0.19828822,0.31213655,0.08630741,-0.29925842,-0.36591454,-0.35089885,453.23503987074747]
